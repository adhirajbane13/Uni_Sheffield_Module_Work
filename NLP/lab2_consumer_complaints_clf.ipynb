# %% [markdown]
# # Introduction
#
# There are lots of applications of text classification in the commercial world. For example, news stories are typically organized by topics; content or products are often tagged by categories; users can be classified into cohorts based on how they talk about a product or brand online.
#
# In the lab, you will be learning to classify Consumer Finance Complaints into one of the 17 pre-defined classes. This is a multi-class text classification problem. We use Python and Jupyter Notebook to develop our system, relying on Scikit-Learn for the machine learning components.

# %% [markdown]
# # Data Exploration
#
# Before diving into training machine learning models, we should look at some examples first and the number of complaints in each class:
#
# In this lab, we need only two columns — “Product” and “Consumer complaint narrative”.
#
# **Input**: Consumer_complaint_narrative
#
# Example: “ I have outdated information on my credit report that I have previously disputed that has yet to be removed this information is more then seven years old and does not meet credit reporting requirements”
#
# **Output**: product
#
# Example: Credit reporting
# We will remove missing values in the “Consumer complaints narrative” column, and add a column encoding the product as an integer because categorical variables are often better represented by integers than strings.
# We also create a couple of dictionaries for future use.
# After cleaning up, this is the first five rows of the data we will be working on:

# %%
import pandas as pd

df = pd.read_csv('./lab2_data.csv')

df['category_id'] = df['Product'].factorize()[0]
from io import StringIO
category_id_df = df[['Product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)

# %%
df.head()
# Out:
#                                              Product  \
# 0  Credit reporting, credit repair services, or o...
# 1  Credit reporting, credit repair services, or o...
# 2          Payday loan, title loan, or personal loan
# 3  Credit reporting, credit repair services, or o...
# 4                        Credit card or prepaid card
#
#                         Consumer_complaint_narrative  category_id
# 0  I sent a letter by certified mail to TRANSUNIO...            0
# 1  I am very distressed that you have included th...            0
# 2  About 4 years ago I went to get a personal loa...            1
# 3  My husband and I bought a new car in XX/XX/XXX...            0
# 4  Early XX/XX/XXXX : Received an unsolicited inv...            2

# %% [markdown]
# # Imbalanced Classes
#
#
# We see that the number of complaints per product is imbalanced. Consumers’ complaints are more biased towards Debt collection, Credit reporting and Mortgage.

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
df.groupby('Product').Consumer_complaint_narrative.count().plot.bar(ylim=0)
plt.show()

# %% [markdown]
# When we encounter such problems, we are bound to have difficulties solving them with standard algorithms. Conventional algorithms are often biased towards the majority class, not taking the data distribution into consideration. In the worst case, minority classes are treated as outliers and ignored. For some cases, such as fraud detection or cancer prediction, we would need to carefully configure our model or artificially balance the dataset, for example by undersampling or oversampling each class.
#
# However, in our case of learning imbalanced data, the majority classes might be of our great interest. It is desirable to have a classifier that gives high prediction accuracy over the majority class, while maintaining reasonable accuracy for the minority classes. Therefore, we will leave it as it is.

# %% [markdown]
# # Text Representation
#
# The classifiers and learning algorithms can not directly process the text documents in their original form, as most of them expect numerical feature vectors with a fixed size rather than the raw text documents with variable length. Therefore, during the preprocessing step, the texts are converted to a more manageable representation.
# One common approach for extracting features from text is to use the bag of words model: a model where for each document, a complaint narrative in our case, the presence (and often the frequency) of words is taken into consideration, but the order in which they occur is ignored.
#
# Specifically, for each term in our dataset, we will calculate a measure called Term Frequency, Inverse Document Frequency, abbreviated to tf-idf. We will use sklearn.feature_extraction.text.TfidfVectorizer to calculate a tf-idf vector for each of consumer complaint narratives:
#
# sublinear_df is set to True to use a logarithmic form for frequency.
# min_df is the minimum numbers of documents a word must be present in to be kept.
# norm is set to l2, to ensure all our feature vectors have a euclidian norm of 1.
# ngram_range is set to (1, 2) to indicate that we want to consider both unigrams and bigrams.
# stop_words is set to "english" to remove all common pronouns ("a", "the", ...) to reduce the number of noisy features.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
labels = df.category_id
features.shape
# Out:
# (6723, 19933)

# %% [markdown]
# Now, each of 6723 consumer complaint narratives is represented by 19933 features, representing the tf-idf score for different unigrams and bigrams.
#
# We can use sklearn.feature_selection.chi2 to find the terms that are the most correlated with each of the products:

# %%
from sklearn.feature_selection import chi2
import numpy as np

N = 2
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names_out())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Product))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'Bank account or service':
#   . Most correlated unigrams:
#        . bank
#        . branch
#   . Most correlated bigrams:
#        . branch manager
#        . overdraft fees
# # 'Checking or savings account':
#   . Most correlated unigrams:
#        . deposited
#        . atm
#   . Most correlated bigrams:
#        . savings account
#        . checking account
# # 'Consumer Loan':
#   . Most correlated unigrams:
#        . car
#        . springleaf
#   . Most correlated bigrams:
#        . 72 months
#        . total payments
# # 'Credit card':
#   . Most correlated unigrams:
#        . target
#        . card
#   . Most correlated bigrams:
#        . best buy
#        . credit card
# # 'Credit card or prepaid card':
#   . Most correlated unigrams:
#        . merchant
#        . card
#   . Most correlated bigrams:
#        . american express
#        . credit card
# # 'Credit reporting':
#   . Most correlated unigrams:
#        . equifax
#        . transunion
#   . Most correlated bigrams:
#        . report equifax
#        . tax lien
# # 'Credit reporting, credit repair services, or other personal consumer reports':
#   . Most correlated unigrams:
#        . accounts
#        . report
#   . Most correlated bigrams:
#        . identity theft
#        . credit report
# # 'Debt collection':
#   . Most correlated unigrams:
#        . collection
#        . debt
#   . Most correlated bigrams:
#        . collection agency
#        . collect debt
# # 'Money transfer, virtual currency, or money service':
#   . Most correlated unigrams:
#        . wire
#        . coinbase
#   . Most correlated bigrams:
#        . money sent
#        . money transfer
# # 'Money transfers':
#   . Most correlated unigrams:
#        . aunt
#        . paypal
#   . Most correlated bigrams:
#        . transferred money
#        . money paypal
# # 'Mortgage':
#   . Most correlated unigrams:
#        . modification
#        . mortgage
#   . Most correlated bigrams:
#        . mortgage company
#        . loan modification
# # 'Other financial service':
#   . Most correlated unigrams:
#        . 980
#        . counseling
#   . Most correlated bigrams:
#        . company ve
#        . credit counseling
# # 'Payday loan':
#   . Most correlated unigrams:
#        . debiting
#        . payday
#   . Most correlated bigrams:
#        . loan lender
#        . payday loan
# # 'Payday loan, title loan, or personal loan':
#   . Most correlated unigrams:
#        . titles
#        . usury
#   . Most correlated bigrams:
#        . personal loan
#        . 00 loan
# # 'Prepaid card':
#   . Most correlated unigrams:
#        . serve
#        . prepaid
#   . Most correlated bigrams:
#        . direct deposit
#        . express serve
# # 'Student loan':
#   . Most correlated unigrams:
#        . loans
#        . navient
#   . Most correlated bigrams:
#        . student loan
#        . student loans
# # 'Vehicle loan or lease':
#   . Most correlated unigrams:
#        . car
#        . repossessed
#   . Most correlated bigrams:
#        . regional acceptance
#        . credit acceptance

# %% [markdown]
# # Training the Logistic Regression model
#
# To train supervised classifiers, we first transformed the “Consumer complaint narrative” into a vector of numbers. We explored vector representations such as TF-IDF weighted vectors.
#
# After having this vector representations of the text we can train supervised classifiers to train unseen “Consumer complaint narrative” and predict the “product” on which they fall.
#
# After all the above data transformation, now that we have all the features and labels, it is time to train the Logistic Regression model.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_score


models = [
    LogisticRegression(random_state=0, max_iter=1000),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %%
import seaborn as sns

sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# /var/folders/9z/w0bwsx4j0t36n687zznt539w0000gq/T/ipykernel_11167/2018125928.py:4: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='model_name', y='accuracy', data=cv_df,

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LogisticRegression    0.681094
# Name: accuracy, dtype: float64

# %% [markdown]
# # Model Evaluation
#
# We are going to look at the confusion matrix, and show the discrepancies between predicted and actual labels.

# %%
from sklearn.model_selection import train_test_split

model = LogisticRegression(random_state=0)

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8,6))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.Product.values, yticklabels=category_id_df.Product.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# The vast majority of the predictions end up on the diagonal (predicted label = actual label), where we want them to be. However, there are a number of misclassifications, and it might be interesting to see what those are caused by:

# %%
from IPython.display import display

for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 6:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['Product', 'Consumer_complaint_narrative']])
      print('')
# Out:
# 'Payday loan, title loan, or personal loan' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 10 examples.
#                                         Product  \
# 4920  Payday loan, title loan, or personal loan
# 4234  Payday loan, title loan, or personal loan
# 4063  Payday loan, title loan, or personal loan
# 4000  Payday loan, title loan, or personal loan
# 2252  Payday loan, title loan, or personal loan
# 2325  Payday loan, title loan, or personal loan
# 1224  Payday loan, title loan, or personal loan
# 1450  Payday loan, title loan, or personal loan
# 2841  I am in receipt of a letter from XXXX XXXX rel...
# 380   i had a credit card with Cabelas. They change ...
# 2301  I am deeply concerned about XXXX XXXX and Bank...
# 2194  I did n't make these charges. They are 100 % u...
# 2384  XXXX  has been non-compliant with removing the...
# 5839  I believe My personal information was stolen w...
# 3046  XXXX card claims I own XXXX but I never opened...
# 3156  USAA Savings Bank XXXX XXXX XXXX XXXX, TX XXXX...
# 2460  I have written to the cfpb in early XX/XX/2019...
# 3180  Without my consent and without notification, m...
# 2259  On XX/XX/2014 I had automatic payment and the ...
# 2631  My social security number has been stolen and ...
# 326   Over 3 years ago, in XX/XX/XXXX I signed up fo...
# 3276  I received a credit card in the mail that I di...
# 978   I AM WRITING TO DISPUTE AN ACCOUNTS FRADULENTL...
# 5877  On XX/XX/20, I received a Citizen Bank credit ...
# 3050  I identified I was a victim of identity theft ...
# 4320  I dont recall this account ever being late. Yo...
# 4395  I have already opted out via the official site...
# 2131  The usbankreliacard that my unemployment benef...
# 5134  When my credit was pulled on     XXXX   XXXX  ...
# 3260  I was late on a payment because of the pandemi...
# 4036  In XXXX of 2019, Discover reported on my credi...
# 4551  Citibank sent me a notice on XX/XX/2017 notify...
# 428   I have had major difficulties with this compan...
# 5727  i was in XXXX and i think the cleaning crew th...
# 4455  I am writing presently in wish to gain your he...
# 'Debt collection' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 77 examples.
#               Product                       Consumer_complaint_narrative
# 3915  Debt collection  I had a collections account for a XXXX Charge ...
# 3955  Debt collection  I've sent multiple letters to this agency abou...
# 1082  Debt collection  XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX X...
# 5422  Debt collection  Hello. Back in 2013 I visited the XXXX XXXX XX...
# 4348  Debt collection  Diversified Consultants h ave placed on all   ...
# ...               ...                                                ...
# 4347  Debt collection  Optimum Outcomes - XXXX XXXX XXXX # XXXX, XXXX...
# 5936  Debt collection  I recently found out due to signing up for a c...
# 799   Debt collection  Paragon Revenue recently reported XXXX collect...
# 203   Debt collection  Additional information for CFPB complaint # XX...
# 1737  Debt collection  this company is destroying my credit with nega...
#
# [77 rows x 2 columns]
# 'Money transfer, virtual currency, or money service' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 7 examples.
#                                                 Product  \
# 6673  Money transfer, virtual currency, or money ser...
# 2426  Money transfer, virtual currency, or money ser...
# 6234  Money transfer, virtual currency, or money ser...
# 861   Money transfer, virtual currency, or money ser...
# 776   Money transfer, virtual currency, or money ser...
# 4714  Money transfer, virtual currency, or money ser...
# 624   Money transfer, virtual currency, or money ser...
#
#                            Consumer_complaint_narrative
# 6673  On XXXX XXXX, 2020, I was at the XXXX XXXX XXX...
# 2426  I have money on hold through zelle and on " XX...
# 6234  PNC Bank does not allow transfers between them...
# 861   I own a small business that accepts credit car...
# 776   They wont allow me to connect to another accou...
# 4714  last month i went on line to my paypal account...
# 624   Intentionally and deliberately, PayPal Inc, mi...
# 'Credit card' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 23 examples.
#           Product                       Consumer_complaint_narrative
# 5614  Credit card  I setup an automatic pay for my Target credit ...
# 5242  Credit card                                     Identity theft
# 1835  Credit card  Two charges were placed on my bill on the same...
# 6615  Vehicle loan or lease  Request for Accounting under Article 9, Sectio...
# 2406  Vehicle loan or lease  Purchased new vehicle and requested to have cr...
# 3732  Vehicle loan or lease  On XX/XX/XXXX I was injured at work. Unfortuna...
# 117   Vehicle loan or lease  FirstBank has been insistently reporting a bal...
# 4918  Vehicle loan or lease  this company is reporting that i have had a au...
# 'Checking or savings account' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 20 examples.
#                           Product  \
# 5409  Checking or savings account
# 3382  Checking or savings account
# 5042  Checking or savings account
# 6390  Checking or savings account
# 2038  Checking or savings account
# 6065  Checking or savings account
# 479   Checking or savings account
# 3063  Checking or savings account
# 2703  Checking or savings account
# 4214  Checking or savings account
# 1116  Checking or savings account
# 3496  Checking or savings account
# 3297  Checking or savings account
# 3509  Checking or savings account
# 3420  Checking or savings account
# 3916  Checking or savings account
# 4543  Checking or savings account
# 1767  Checking or savings account
# 1067  Checking or savings account
# 1424  Checking or savings account
#
#                            Consumer_complaint_narrative
# 5409  I opened an IRA account in XX/XX/XXXX with XXX...
# 3382  WE OPENED 2 CREDIT CARDS WITH BANK OF AMERICA ...
# 5042  Wells Fargo bank allowed XXXX $ of UNAUTHORIZE...
# 6390  Car accident Attorney XXXX XXXX XXXX Of XXXX X...
# 2038  a thief used a phony driver license to steal m...
# 6065  Account was closed by USAA for no reason and w...
# 479   I believe that I am a victim of fraud and /or ...
# 3063  For my account ending in XXXX, SunTrust looked...
# 2703  Some one hacked into my Regions Bank account a...
# 4214  Capital One is blocking me from enabling exter...
# 1116  I am emailing in regards to cash app changing ...
# 3496  I currently have joint checking and savings ba...
# 3297  XX/XX/XXXX and XXXX. Excessive overdraft fees,...
# 3509  I contacted BBVA Compass Bank after I noticed ...
# 3420  Back last Tuesday ( XXXX-2018 ). XXXX XXXX was...
# 3916  PNC has problems linking services such as XXXX...
# 4543  payments for my ex wife bills were being paid ...
# 1767  It has been almost 2 years since i have tried ...
# 1067  I have spent 2 hours typing this and this webp...
# 1424  XX/XX/XXXX To : Bank of America & XXXX XXXX XX...
# 'Mortgage' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 17 examples.
#        Product                       Consumer_complaint_narrative
# 6666  Mortgage  Ocwen Loan Servicing has violated 12 CFR 226.1...
# 5799  Mortgage  I have had a HELOC with PNC Bank for many year...
# 3864  Mortgage  I attempted to cancel an automatic payment, bu...
# 976   Mortgage  I tried getting a personal loan with my credit...
# 6349  Mortgage  I contact a Shellpoint Mortgage Company custom...
# 5506  Mortgage  The house shows a volunteer repo i never agree...
# 2043  Mortgage  In their response to complaint XXXX, Springlea...
# 3375  Mortgage  AN UNKNOWN ERROR IS FALSELY REPORTING A 30 DAY...
# 1750  Mortgage  I entered into a hardship program with XXXX XX...
# 5292  Mortgage  For about the last 6 to 8 months Discover Bank...
# 3092  Mortgage  I n 2006, I  purchased the   XXXX   XXXX   XXX...
# 2033  Mortgage  I have been a regular payer of mortgage from m...
# 4278  Mortgage  Loan No. XXXX XXXX XXXX XXXX XXXX, XXXX, OR XX...
# 325   Mortgage  On XX/XX/19 I mailed a dispute to OCWEN Loan S...
# 5883  Mortgage  i requested for my full payment history for th...
# 1191  Mortgage  I applied for a refinance through an offer wit...
# 1752  Mortgage  I received an escrow check in my deceased husb...
# 'Credit reporting' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 92 examples.
#                Product                       Consumer_complaint_narrative
# 3325  Credit reporting  I have unauthorized and fraudulent inquiries a...
# 3007  Credit reporting  My credit report is showing the name XXXX XXXX...
# 287   Credit reporting  All the major credit reporting agencies, Trans...
# 4774  Credit reporting  I have a lot of fraudulent inquiries that are ...
# 4873  Credit reporting  I wrote to TransUnion in XX/XX/XXXX to dispute...
# ...                ...                                                ...
# 4540  Credit reporting  Equifax continues to report a tradeline for th...
# 2161  Credit reporting  I have been a victim of Identity Theft. I have...
# 5326  Credit reporting  I have not owe a home sent XX/XX/XXXX. XXXX Co...
# 1418  Credit reporting  On or about I sent in a dispute to Experian re...
# 5893  Credit reporting  I filed several times before complaints agains...
#
# [92 rows x 2 columns]
# 'Student loan' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 11 examples.
#            Product                       Consumer_complaint_narrative
# 6507  Student loan  XXXX parent plus loan..paid on time for 5.5 ye...
# 444   Student loan  MY STUDENT LOAN IS BEING REPORTED AS 120 DAYS ...
# 1411  Student loan  My monthly amount has steadily gone up. Every ...
# 4157  Student loan  In XXXX, I got a loan with Wells Fargo a XXXX ...
# 3369  Student loan  In 2006 I signed my student loan promissary no...
# 2527  Student loan  I was credited only seven qualifying loan forg...
# 3428  Student loan  Fed loan uses online address system. I never c...
# 1142  Student loan  Wells Fargo sold my loan to another provider (...
# 5843  Student loan  I recieve a loan from XXXX on XXXX \nCould not...
# 2310  Student loan  Charged late fees by Navient after they were n...
# 6718  Student loan  There are XXXX student loan accounts for my Da...
# 'Consumer Loan' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 9 examples.
#             Product                       Consumer_complaint_narrative
# 2433  Consumer Loan  XXXX XXXX, XXXX The information below is the s...
# 1220  Consumer Loan  This car was a total loss XX/XX/XXXX. The pay ...
# 4941  Consumer Loan  Ally Bank had an account for my XX/XX/XXXX XXX...
# 1900  Consumer Loan  My complaint is with First Merit Bank ( XXXX, ...
# 5194  Consumer Loan  The prospective loan company financing a new c...
# 1804  Consumer Loan  JPMORGAN CHASE is reporting my auto loan erron...
# 6367  Consumer Loan  It was brought to my attention that a " Negati...
# 6409  Consumer Loan  XXXX XXXX MILES ( XXXX MINUTES ) FROM AIRPORT ...
# 4891  Consumer Loan  I leased a car from ALLY Bank and was charged ...
# 'Bank account or service' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 10 examples.
#                       Product  \
# 4595  Bank account or service
# 6289  Bank account or service
# 4841  Bank account or service
# 1277  Bank account or service
# 1922  Bank account or service
# 4848  Bank account or service
# 6357  Bank account or service
# 6202  Bank account or service
# 2217  Bank account or service
# 4407  Bank account or service
#
#                            Consumer_complaint_narrative
# 4595  I received an offer to apply for a Citibank Ci...
# 6289  my applying to open the account of First Tenne...
# 4841  Wells Fargo ( WF ) was my bank for a period of...
# 'Payday loan, title loan, or personal loan' predicted as 'Debt collection' : 13 examples.
#                                         Product  \
# 4379  Payday loan, title loan, or personal loan
# 5392  Payday loan, title loan, or personal loan
# 6645  Payday loan, title loan, or personal loan
# 6584  Payday loan, title loan, or personal loan
# 2564  Payday loan, title loan, or personal loan
# 4441  Payday loan, title loan, or personal loan
# 3498  Payday loan, title loan, or personal loan
# 3993  Payday loan, title loan, or personal loan
# 4603  Payday loan, title loan, or personal loan
# 282   Payday loan, title loan, or personal loan
# 378   Payday loan, title loan, or personal loan
# 253   Payday loan, title loan, or personal loan
# 4041  Payday loan, title loan, or personal loan
#
#                            Consumer_complaint_narrative
# 4379  I received a personal loan back In XXXX for XX...
# 5392  On XX/XX/18 I contacted Tower Loan in XXXX XXX...
# 6645  XX/XX/2018, I called American First Finance ab...
# 6584  Called their customer service phone number Tue...
# 2564  Hi - I have several synchrony bank loans that ...
# 4441  XX/XX/XXXX I took out a loan/line of credit wi...
# 3498  XXXX has recently contacted me, telling me tha...
# 3993  I took out a loan in XXXX. I am elderly and on...
# 4603  I received a loan for $ XXXX {$800.00} from 1s...
# 282   I paid big picture loan ahead of time to avoid...
# 378   My balance just keeps increases no matter the ...
# 253   On Friday XX/XX/2019 I received a call from Lo...
# 4041  To : Consumer Financial Protection Bureau XX/X...
# 'Credit card or prepaid card' predicted as 'Debt collection' : 12 examples.
#                           Product  \
# 4999  Credit card or prepaid card
# 1828  Credit card or prepaid card
# 2836  Credit card or prepaid card
# 2709  Credit card or prepaid card
# 729   Credit card or prepaid card
# 6283  Credit card or prepaid card
# 2092  Credit card or prepaid card
# 3618  Credit card or prepaid card
# 534   Credit card or prepaid card
# 3586  Credit card or prepaid card
# 5919  Credit card or prepaid card
# 2141  Credit card or prepaid card
#
#                            Consumer_complaint_narrative
# 4999  My wife opened a credit card in her name and h...
# 1828  I was introduced to the idea of borrowing mone...
# 2836  Today, XXXX/XXXX/19, I arrived home and found ...
# 2709  My husband and I lost our jobs last year and h...
# 729   I ordered a bed, and nightstand from XXXX on X...
# 6283  I have repeatedly disputed this account, the c...
# 2092  I opened an account in  XXXX  of   XXXX   as a...
# 3618  To : Capital One XXXX XXXX XXXX XXXX XXXX XXXX...
# 534   I have been a bluebird American Express client...
# 3586  I called to close the account and asked for a ...
# 5919  Hi, I had a XXXX XXXX credit card with a small...
# 2141  so my mom flipped out on the phone w/ XXXX XXX...
# 'Money transfer, virtual currency, or money service' predicted as 'Debt collection' : 9 examples.
#                                                 Product  \
# 1568  Money transfer, virtual currency, or money ser...
# 1270  Money transfer, virtual currency, or money ser...
# 3994  Money transfer, virtual currency, or money ser...
# 5737  Money transfer, virtual currency, or money ser...
# 4853  Money transfer, virtual currency, or money ser...
# 2429  Money transfer, virtual currency, or money ser...
# 6078  Money transfer, virtual currency, or money ser...
# 4436  Money transfer, virtual currency, or money ser...
# 5327  Money transfer, virtual currency, or money ser...
#
#                            Consumer_complaint_narrative
# 1568  I have signed up for a service through  XXXX  ...
# 1270  I went to DolEx express at XXXX meat market, X...
# 3994  My complaint is with M & T and their lack of c...
# 5737  Coinbase XXXX # XXXX Coinbase / XXXX have susp...
# 4853  I went to XXXX in XXXX In where a employee of ...
# 2429  On Saturday, XX/XX/XXXX, around XXXX I began a...
# 6078  I have two Certificates of Deposit dated XX/XX...
# 4436  paypal steal my money, They took the money out...
# 5327  I am trying to close my PayPal account associa...
# 'Credit card' predicted as 'Debt collection' : 14 examples.
#           Product                       Consumer_complaint_narrative
# 1593  Credit card  HELLO. \nTHIS PARAGRAPH IS SUPLIMENTAL TO THE ...
# 1196  Credit card  Ever since XXXX XXXX has joined with the colle...
# 1811  Credit card  On XX/XX/2017 I mailed a letter in response to...
# 3931  Credit card  On XXXX/XXXX/2015 I purchased a refrigerator f...
# 4031  Credit card  CAPITAL ONE BANK USA ACCOUNT NUMBERs : XXXX XX...
# 1330  Credit card  Opened Capital One Bank account in XXXX, 17 ye...
# 5301  Credit card  Eleven years ago I lost my job then had a prob...
# 2707  Credit card  I had a family death of my mother and she is i...
# 4834  Credit card  In XXXX of XXXX, I opened an account with Citi...
# 3580  Credit card  In 2008 I lived in a shelter for XXXX and had ...
# 5929  Credit card  I lost my job a few years ago, and have been h...
# 3294  Credit card  My monthly minimum payments are 5 %. I pay my ...
# 5358  Credit card  I made my regular payment on XXXX/XXXX/2016 of...
# 1223  Credit card  Chase bank is reporting a charged off credit c...
# 'Vehicle loan or lease' predicted as 'Debt collection' : 12 examples.
#                     Product                       Consumer_complaint_narrative
# 4855  Vehicle loan or lease  Since XX/XX/XXXX, I have been trying to get a ...
# 1267  Vehicle loan or lease  This is emails in which I have submitted to Al...
# 2182  Vehicle loan or lease  It is about a XXXX car that I no longer have. ...
# 6244  Vehicle loan or lease  In XX/XX/XXXX we were approved for a holiday p...
# 5933  Vehicle loan or lease  Collins Asset Group claims I owe them $XXXX fo...
# 949   Vehicle loan or lease  My vehicle loan was being serviced by XXXX XXX...
# 6067  Vehicle loan or lease  XX/XX/XXXX : called Toyota to do a voluntary r...
# 5910  Vehicle loan or lease  I RECEIVED A LETTER IN XXXX REGARDING THE WELL...
# 5634  Vehicle loan or lease  Called ally finance about gap and warranty pro...
# 854   Vehicle loan or lease  I had filed a complaint previously. The banks ...
# 4888  Vehicle loan or lease  I have a lease with Ally Bank, my vehicle was ...
# 1850  Vehicle loan or lease  In XX/XX/XXXX, I signed a two year lease with ...
# 'Mortgage' predicted as 'Debt collection' : 9 examples.
#        Product                       Consumer_complaint_narrative
# 1974  Mortgage  Asked in writing that my PMI be canceled and a...
# 4937  Mortgage  After being told that my number was being take...
# 2235  Mortgage  On XX/XX/XXXX the check we wrote that paid the...
# 2971  Mortgage  Wednesday XX/XX/XXXX : New American Funding st...
# 2529  Mortgage  Re : erroneous item XXXX XXXX XXXX # XXXX repo...
# 5762  Mortgage  I purchased a home XX/XX/2020 and Midwest Loan...
# 6525  Mortgage  This is a disputed response to previously file...
# 3374  Mortgage  Im asking this agency to investigate this tria...
# 3669  Mortgage  We updated our mortgage auto payment online an...
# 'Credit reporting' predicted as 'Debt collection' : 6 examples.
#                Product                       Consumer_complaint_narrative
# 5621  Credit reporting  I moved out of my apartment and had a disputed...
# 3425  Credit reporting  Satisfied Judgment Filed XXXX ; XXXX XXXX XXXX...
# 5622  Credit reporting  I had a medical bill for XXXX XXXX Medical Cen...
# 531   Credit reporting  I have contacted the credit reporting company,...
# 3697  Credit reporting  This company is reporting a tax lien that has ...
# 31    Credit reporting  Check systems is continually breaking the law ...
# 'Student loan' predicted as 'Debt collection' : 15 examples.
#            Product                       Consumer_complaint_narrative
# 3731  Student loan  I am XXXX XXXX XXXX and XXXX XXXX veteran due ...
# 170   Student loan  I have XXXX loan which has the same account nu...
# 994   Student loan  My original payment was set at {$50.00} around...
# 4406  Student loan  I went out on XXXX form school and NelNet pick...
# 5233  Student loan  I have contacted FEDLOAN on numerous occasions...
# 2647  Student loan  I keep getting calls from this number ( XXXX )...
# 66    Student loan  Earlier this month, my payment was increased f...
# 2132  Student loan  I have been contacting Action Financial servic...
# 977   Student loan  Company has repeatedly mismanaged {$430000.00}...
# 6324  Student loan  I have mailed a detailed letter to Navient und...
# 5608  Student loan  XXXX XXXX University offered me a No payments ...
# 898   Student loan  I have disputed this account and have reached ...
# 4649  Student loan  The company is Navient and this is for a priva...
# 1525  Student loan  several times I have made an attempt to resolv...
# 6207  Student loan  XXXX college send me to collections, after hav...
# 'Consumer Loan' predicted as 'Debt collection' : 13 examples.
#             Product                       Consumer_complaint_narrative
# 2984  Consumer Loan  Our son purchased a vehicle and had it finance...
# 4519  Consumer Loan  On XX/XX/2015 I went to the Car Max dealership...
# 6647  Consumer Loan  Checking my credit without my permission. Also...
# 6169  Consumer Loan  hyundai finance uses discriminatory tactics to...
# 6537  Consumer Loan  I purchased a computer through Conn 's utilizi...
# 5550  Consumer Loan  Harassment, Trying to collect more than owed, ...
# 4396  Consumer Loan  The branch office filing lawsuits in magistrat...
# 6698  Consumer Loan  Harley Davidson is calling the office for debt...
# 1597  Consumer Loan  I am currently making payments to Automobile A...
# 6721  Consumer Loan  hello my name is XXXX XXXX, and I was aggressi...
# 5739  Consumer Loan  I was recently in a car accident and my car wa...
# 2234  Consumer Loan  I got a loan to pay for XXXX but the XXXX neve...
# 1691  Consumer Loan  A long-time customer of ACE Cash express, I to...
# 'Bank account or service' predicted as 'Debt collection' : 15 examples.
#                       Product  \
# 5096  Bank account or service
# 2262  Bank account or service
# 2355  Bank account or service
# 4309  Bank account or service
# 1892  Bank account or service
# 4557  Bank account or service
# 1778  Bank account or service
# 3831  Bank account or service
# 2189  Bank account or service
# 5965  Bank account or service
# 5532  Bank account or service
# 1065  Bank account or service
# 5951  Bank account or service
# 3032  Bank account or service
# 728   Bank account or service
#
#                            Consumer_complaint_narrative
# 5096  Us Bank charged me fees for items that cleared...
# 2262  I would like to add to my complaint ( case num...
# 2355  I would like to lodge a formal complaint about...
# 4309  The representatives of XXXX went to Wells Farg...
# 1892  I am being stalked by a US Bank employee who c...
# 4557  I was attempting to move money from my PayPal ...
# 1778  I was frauded against and when I filed a claim...
# 3831  I contacted Wells Fargo to request XXXX checks...
# 2189  I got restriction with my bank Capitol One 360...
# 5965  # 1 -- PayPal/Ebay Inc Auction where as XXXX t...
# 5532  I got a reminder notice from XXXX XXXX claimin...
# 1065  Here is the letter i sent it to the bank throu...
# 5951  I have a PayPal account and was recently advis...
# 3032  Wells Fargo failed to stop debits from XXXX af...
# 728   Hello My Paypal Account was suspended in XXXX ...
# 'Money transfer, virtual currency, or money service' predicted as 'Checking or savings account' : 14 examples.
#                                                 Product  \
# 4330  Money transfer, virtual currency, or money ser...
# 3476  Money transfer, virtual currency, or money ser...
# 472   Money transfer, virtual currency, or money ser...
# 5459  Money transfer, virtual currency, or money ser...
# 6608  Money transfer, virtual currency, or money ser...
# 3266  Money transfer, virtual currency, or money ser...
# 5083  Money transfer, virtual currency, or money ser...
# 5451  Money transfer, virtual currency, or money ser...
# 4213  Money transfer, virtual currency, or money ser...
# 3241  Money transfer, virtual currency, or money ser...
# 893   Money transfer, virtual currency, or money ser...
# 5094  Money transfer, virtual currency, or money ser...
# 5499  Money transfer, virtual currency, or money ser...
# 6619  Money transfer, virtual currency, or money ser...
#
#                            Consumer_complaint_narrative
# 4330  I sent a wire with below details and i was tol...
# 3476  On XX/XX/2020 I attempted to add funds to the ...
# 472   I had a balance of {$1700.00} in my Venmo acco...
# 5459  I have an account with Coinbase and have XXXX ...
# 6608  On XX/XX/ 2020, I tried to send money using In...
# 3266  On XXXX XX/XX/2020. i made an attempt to trans...
# 5083  XX/XX/19, {$460.00} - rental scam. I found a r...
# 5451  On XX/XX/2020 I transferred {$500.00} from my ...
# 4213  I am having an issue with Coinbase and was adv...
# 3241  On XX/XX/2019, I met with Detective XXXX XXXX,...
# 893   On XX/XX/2016, my colleague XXXX XXXX and I en...
# 5094  Respected CFPB Officer, My previous employer s...
# 5499  Pnc will not connect with my other bank via on...
# 6619  I started working for a new company, and in th...
# 'Bank account or service' predicted as 'Checking or savings account' : 25 examples.
#                       Product  \
# 6248  Bank account or service
# 2345  Bank account or service
# 4762  Bank account or service
# 4578  Bank account or service
# 302   Bank account or service
# 4812  Bank account or service
# 2134  Bank account or service
# 3690  Bank account or service
# 1290  Bank account or service
# 5888  Bank account or service
# 5255  Bank account or service
# 5260  Bank account or service
# 6126  Bank account or service
# 4694  Bank account or service
# 5584  Bank account or service
# 6128  Bank account or service
# 5625  Bank account or service
# 3321  Bank account or service
# 3438  Bank account or service
# 2070  Bank account or service
# 4786  Bank account or service
# 3251  Bank account or service
# 655   Bank account or service
# 2140  Bank account or service
# 6498  Bank account or service
#
#                            Consumer_complaint_narrative
# 6248  Astoria Bank charged me an overdraft fee after...
# 2345  Issue 1 - Events : XXXX. There were many fraud...
# 4762  I opened a Huntington checking acct because of...
# 4578  Today is XX/XX/2016 After me receiving my dire...
# 302   I paid off my loan with ally bank back in XXXX...
# 4812  I recently contacted Bank Of America for a dis...
# 2134  At a Well 's Fargo Bank, I moved money from my...
# 3690  In XXXX 2016, I was prompted to open a Citiban...
# 1290  Hello, After receiving a promotional offer cod...
# 5888  I met with a financial counselor who checked m...
# 5255  In XX/XX/2012, when mobile deposit was taking ...
# 5260  There was a Deposit applied to our account in ...
# 6126  I opened a bank account at Garden State Commun...
# 4694  On XXXX/XXXX/15 my car was broken into at a pa...
# 5584  Bank of America constantly ads fees before I c...

# %% [markdown]
# # 020 Reading data
#
# > COM6018
#
# *Copyright &copy; 2023 Jon Barker, University of Sheffield. All rights reserved*.
#
# In this lab class we are going to be working with some real datasets that store atmospheric carbon dioxide and methane concentrations measured over several decades. We will read the data from csv files and do all the data processing using the Python standard library and ideas that we saw in the previous lab class. Our aim will be to plot an easily interpretable graph that shows how the concentration of these gases has changed over time.
#
# If you have used numpy and pandas packages before, you may realise that these would make this task easier, and indeed, this is the basic point of this lab. By first seeing how things would be done in pure Python, we will better appreciate the benefits of using specialised data science packages when we come to study them in the next couple of weeks.

# %% [markdown]
# ## Step 1 - Reading in the CO2 data
#
# The data is stored in two files
#
# - `data/co2.csv`  - the carbon diaoxide data
# - `data/ch4.csv`  - the methane data
#
# Write a function called `read_co2_csv` that takes the file name and returns a list of dictionaries storing the data. i.e. the 'co2.csv' file would be read with,
#
# ```python
# co2_data = read_csv('data/co2.csv')
# ```
#
# Hint: Use the csv.DictReader function and refer to the course notes if you need to.  You will need to manually set the fieldnames parameter of the csv.DictReader to the correct value, i.e., `['Yr', 'Mn', 'Dy', 'CO2', 'NB', 'scale']`
#
# You will also find that the first twenty of so items are not valid because the csv file has 'comment lines' starting with a '%' symbol. DictReader does not know how to skip these lines and will try to read them as data.  Try to think how you can filter out these entries in a general way. If you can't manage this just count how many invalid lines there are and remove them from the list of dictionaries before returning the list from your function eg.  list_of_dicts = list_of_dicts[20:]
#
# After you have written your function, run the test cell below to check that it works.

# %%
# WRITE SOLUTION HERE
import csv
def read_co2_csv(filename):
    with open(filename) as csvfile:
        co2_reader = csv.DictReader(csvfile,fieldnames = ['Yr', 'Mn', 'Dy', 'CO2', 'NB', 'scale'], skipinitialspace = True)
        data = [row for row in co2_reader]
    return data[34:]
co2_data = read_co2_csv('data/co2.csv')
print(co2_data[0])
# Out:
# {'Yr': '1958', 'Mn': '01', 'Dy': '01', 'CO2': 'NaN', 'NB': '0', 'scale': '12.0'}

# %%
co2_data
# Out:
# [{'Yr': '1958',
#   'Mn': '01',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '01',
#   'Dy': '31',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '02',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '30',
#   'CO2': '316.16',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '03',
#   'Dy': '31',
#   'CO2': '316.69',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '02',
#   'CO2': '317.67',
#   'NB': '3',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '03',
#   'CO2': '317.76',
#   'NB': '4',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '04',
#   'CO2': '317.09',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '05',
#   'CO2': '317.36',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '06',
#   'CO2': '317.80',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '09',
#   'CO2': '315.90',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '13',
#   'CO2': '318.39',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '14',
#   'CO2': '318.41',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '17',
#   'CO2': '317.74',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '18',
#   'CO2': '317.80',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '20',
#   'CO2': '316.52',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '21',
#   'CO2': '317.01',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '22',
#   'CO2': '317.25',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '04',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '02',
#   'CO2': '316.84',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '03',
#   'CO2': '316.40',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '04',
#   'CO2': '316.76',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '05',
#   'CO2': '317.69',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '06',
#   'CO2': '317.84',
#   'NB': '21',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '20',
#   'CO2': '317.70',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '21',
#   'CO2': '317.98',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '22',
#   'CO2': '318.09',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '23',
#   'CO2': '317.94',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '05',
#   'Dy': '31',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '06',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '04',
#   'CO2': '316.94',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '08',
#   'CO2': '315.84',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '14',
#   'CO2': '316.22',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '15',
#   'CO2': '316.55',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '16',
#   'CO2': '314.55',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '17',
#   'CO2': '314.56',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '19',
#   'CO2': '315.72',
#   'NB': '4',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '20',
#   'CO2': '316.04',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '23',
#   'CO2': '315.90',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '24',
#   'CO2': '316.09',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '26',
#   'CO2': '315.25',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '27',
#   'CO2': '315.61',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '28',
#   'CO2': '315.53',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '30',
#   'CO2': '315.74',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '07',
#   'Dy': '31',
#   'CO2': '315.76',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '04',
#   'CO2': '315.29',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '05',
#   'CO2': '314.92',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '06',
#   'CO2': '315.54',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '07',
#   'CO2': '314.78',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '11',
#   'CO2': '315.23',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '12',
#   'CO2': '314.99',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '13',
#   'CO2': '314.82',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '14',
#   'CO2': '315.08',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '15',
#   'CO2': '315.27',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '08',
#   'Dy': '31',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '01',
#   'CO2': '314.23',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '09',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '10',
#   'Dy': '31',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '07',
#   'CO2': '313.32',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '08',
#   'CO2': '313.32',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '09',
#   'CO2': '313.15',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '12',
#   'CO2': '313.48',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '13',
#   'CO2': '313.11',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '14',
#   'CO2': '313.07',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '15',
#   'CO2': '313.31',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '16',
#   'CO2': '313.47',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '17',
#   'CO2': '313.35',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '18',
#   'CO2': '313.44',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '19',
#   'CO2': '313.17',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '20',
#   'CO2': '313.17',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '21',
#   'CO2': '313.92',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '22',
#   'CO2': '313.71',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '23',
#   'CO2': '314.01',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '24',
#   'CO2': '313.98',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '26',
#   'CO2': '313.87',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '27',
#   'CO2': '313.91',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '28',
#   'CO2': '314.28',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '29',
#   'CO2': '313.74',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '11',
#   'Dy': '30',
#   'CO2': '313.84',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '01',
#   'CO2': '314.30',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '02',
#   'CO2': '314.22',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '03',
#   'CO2': '314.15',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '04',
#   'CO2': '314.44',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '05',
#   'CO2': '314.55',
#   'NB': '22',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '06',
#   'CO2': '314.24',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '07',
#   'CO2': '314.84',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '08',
#   'CO2': '314.62',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '09',
#   'CO2': '314.36',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '10',
#   'CO2': '313.86',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '11',
#   'CO2': '314.29',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '12',
#   'CO2': '314.53',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '13',
#   'CO2': '314.52',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '14',
#   'CO2': '314.74',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '15',
#   'CO2': '314.68',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '16',
#   'CO2': '314.33',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '17',
#   'CO2': '314.53',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '18',
#   'CO2': '315.08',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '20',
#   'CO2': '315.02',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '21',
#   'CO2': '314.91',
#   'NB': '20',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '22',
#   'CO2': '314.76',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '23',
#   'CO2': '314.86',
#   'NB': '21',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '24',
#   'CO2': '315.10',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '25',
#   'CO2': '315.09',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '26',
#   'CO2': '315.58',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '27',
#   'CO2': '315.56',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '29',
#   'CO2': '315.04',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '30',
#   'CO2': '315.26',
#   'NB': '23',
#   'scale': '12.0'},
#  {'Yr': '1958',
#   'Mn': '12',
#   'Dy': '31',
#   'CO2': '315.44',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '01',
#   'CO2': '315.23',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '05',
#   'CO2': '315.02',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '06',
#   'CO2': '315.58',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '07',
#   'CO2': '315.14',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '08',
#   'CO2': '315.43',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '09',
#   'CO2': '315.70',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '10',
#   'CO2': '315.58',
#   'NB': '20',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '11',
#   'CO2': '315.68',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '12',
#   'CO2': '315.52',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '13',
#   'CO2': '315.28',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '14',
#   'CO2': '315.90',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '15',
#   'CO2': '316.17',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '16',
#   'CO2': '316.03',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '17',
#   'CO2': '315.53',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '18',
#   'CO2': '315.44',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '19',
#   'CO2': '315.04',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '20',
#   'CO2': '315.64',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '21',
#   'CO2': '315.77',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '22',
#   'CO2': '315.91',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '23',
#   'CO2': '315.59',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '24',
#   'CO2': '316.01',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '25',
#   'CO2': '315.84',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '26',
#   'CO2': '315.80',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '28',
#   'CO2': '315.41',
#   'NB': '4',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '29',
#   'CO2': '315.56',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '01',
#   'Dy': '31',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '17',
#   'CO2': '316.94',
#   'NB': '3',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '18',
#   'CO2': '316.68',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '19',
#   'CO2': '316.42',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '20',
#   'CO2': '316.20',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '22',
#   'CO2': '316.81',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '23',
#   'CO2': '317.17',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '24',
#   'CO2': '316.91',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '26',
#   'CO2': '316.56',
#   'NB': '3',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '27',
#   'CO2': '316.41',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '02',
#   'Dy': '28',
#   'CO2': '316.48',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '01',
#   'CO2': '316.87',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '03',
#   'CO2': '316.90',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '04',
#   'CO2': '316.78',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '05',
#   'CO2': '316.92',
#   'NB': '23',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '06',
#   'CO2': '316.65',
#   'NB': '23',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '07',
#   'CO2': '316.58',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '08',
#   'CO2': '316.76',
#   'NB': '20',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '09',
#   'CO2': '317.33',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '10',
#   'CO2': '316.68',
#   'NB': '22',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '15',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '17',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '21',
#   'CO2': '316.97',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '22',
#   'CO2': '317.09',
#   'NB': '20',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '23',
#   'CO2': '317.05',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '24',
#   'CO2': '316.38',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '25',
#   'CO2': '316.53',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '26',
#   'CO2': '316.62',
#   'NB': '20',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '27',
#   'CO2': '316.46',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '28',
#   'CO2': '317.09',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '29',
#   'CO2': '317.03',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '30',
#   'CO2': '316.37',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '03',
#   'Dy': '31',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '01',
#   'CO2': '316.50',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '02',
#   'CO2': '318.15',
#   'NB': '4',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '03',
#   'CO2': '318.16',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '05',
#   'CO2': '317.08',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '06',
#   'CO2': '317.14',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '07',
#   'CO2': '317.55',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '08',
#   'CO2': '316.92',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '09',
#   'CO2': '316.91',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '10',
#   'CO2': '317.42',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '11',
#   'CO2': '317.07',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '12',
#   'CO2': '316.84',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '13',
#   'CO2': '316.96',
#   'NB': '21',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '14',
#   'CO2': '317.48',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '15',
#   'CO2': '317.40',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '16',
#   'CO2': '317.30',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '17',
#   'CO2': '316.78',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '18',
#   'CO2': '317.43',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '19',
#   'CO2': '317.79',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '20',
#   'CO2': '318.31',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '21',
#   'CO2': '318.53',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '22',
#   'CO2': '318.26',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '24',
#   'CO2': '318.61',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '25',
#   'CO2': '318.53',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '26',
#   'CO2': '318.53',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '27',
#   'CO2': '318.18',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '28',
#   'CO2': '318.16',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '29',
#   'CO2': '318.36',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '04',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '03',
#   'CO2': '318.33',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '04',
#   'CO2': '318.15',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '05',
#   'CO2': '318.44',
#   'NB': '3',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '11',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '13',
#   'CO2': '318.35',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '14',
#   'CO2': '318.53',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '15',
#   'CO2': '318.72',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '16',
#   'CO2': '317.17',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '17',
#   'CO2': '317.71',
#   'NB': '3',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '18',
#   'CO2': '317.93',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '19',
#   'CO2': '318.30',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '20',
#   'CO2': '318.50',
#   'NB': '20',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '21',
#   'CO2': '318.65',
#   'NB': '20',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '22',
#   'CO2': '318.56',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '23',
#   'CO2': '317.81',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1959',
#   'Mn': '05',
#   'Dy': '24',
#   'CO2': '318.42',
# ...
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '13',
#   'CO2': '318.98',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '14',
#   'CO2': '318.66',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '15',
#   'CO2': '318.87',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '16',
#   'CO2': '318.65',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '17',
#   'CO2': '318.93',
#   'NB': '18',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '18',
#   'CO2': '319.11',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '19',
#   'CO2': '318.44',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '20',
#   'CO2': '319.24',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '21',
#   'CO2': '318.43',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '22',
#   'CO2': '319.12',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '23',
#   'CO2': '318.82',
#   'NB': '23',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '24',
#   'CO2': '319.00',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '25',
#   'CO2': '318.99',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '26',
#   'CO2': '319.59',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '27',
#   'CO2': '319.73',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '04',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '03',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '05',
#   'CO2': '320.05',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '06',
#   'CO2': '320.00',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '07',
#   'CO2': '320.31',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '08',
#   'CO2': '320.26',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '09',
#   'CO2': '319.19',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '10',
#   'CO2': '320.20',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '11',
#   'CO2': '319.98',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '14',
#   'CO2': '319.85',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '15',
#   'CO2': '319.58',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '16',
#   'CO2': '319.49',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '17',
#   'CO2': '319.88',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '18',
#   'CO2': '320.23',
#   'NB': '22',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '19',
#   'CO2': '320.34',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '20',
#   'CO2': '320.26',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '21',
#   'CO2': '320.12',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '22',
#   'CO2': '319.66',
#   'NB': '22',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '24',
#   'CO2': '319.56',
#   'NB': '3',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '25',
#   'CO2': '319.75',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '26',
#   'CO2': '320.16',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '27',
#   'CO2': '319.78',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '28',
#   'CO2': '319.52',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '29',
#   'CO2': '320.18',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '30',
#   'CO2': '320.64',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '05',
#   'Dy': '31',
#   'CO2': '320.02',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '01',
#   'CO2': '319.94',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '03',
#   'CO2': '319.03',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '05',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '08',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '09',
#   'CO2': '320.40',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '10',
#   'CO2': '320.27',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '11',
#   'CO2': '320.03',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '12',
#   'CO2': '320.20',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '13',
#   'CO2': '319.77',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '14',
#   'CO2': '319.81',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '15',
#   'CO2': '319.65',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '16',
#   'CO2': '319.57',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '17',
#   'CO2': '319.22',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '18',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '22',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '23',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '24',
#   'CO2': '319.15',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '25',
#   'CO2': '319.20',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '26',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '27',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '28',
#   'CO2': '318.43',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '29',
#   'CO2': '318.88',
#   'NB': '18',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '06',
#   'Dy': '30',
#   'CO2': '318.37',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '01',
#   'CO2': '318.18',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '02',
#   'CO2': '317.62',
#   'NB': '1',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '03',
#   'CO2': '317.55',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '05',
#   'CO2': '318.30',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '07',
#   'CO2': '318.42',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '08',
#   'CO2': '318.68',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '09',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '11',
#   'CO2': '318.59',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '12',
#   'CO2': '318.65',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '13',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '14',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '15',
#   'CO2': '318.45',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '16',
#   'CO2': '318.56',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '17',
#   'CO2': '318.62',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '18',
#   'CO2': '318.26',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '19',
#   'CO2': '318.25',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '20',
#   'CO2': '318.03',
#   'NB': '24',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '21',
#   'CO2': '317.90',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '22',
#   'CO2': '318.13',
#   'NB': '23',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '23',
#   'CO2': '317.92',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '24',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '25',
#   'CO2': '317.87',
#   'NB': '4',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '26',
#   'CO2': '317.94',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '27',
#   'CO2': '317.82',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '28',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '29',
#   'CO2': '316.31',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '30',
#   'CO2': '316.66',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '07',
#   'Dy': '31',
#   'CO2': '317.12',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '01',
#   'CO2': '317.09',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '02',
#   'CO2': '317.27',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '03',
#   'CO2': '315.48',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '04',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '05',
#   'CO2': '317.28',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '06',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '07',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '08',
#   'CO2': '316.55',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '09',
#   'CO2': '314.90',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '10',
#   'CO2': '316.77',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '11',
#   'CO2': '317.10',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '12',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '13',
#   'CO2': '316.94',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '14',
#   'CO2': '316.25',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '15',
#   'CO2': '316.28',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '16',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '17',
#   'CO2': '316.30',
#   'NB': '13',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '18',
#   'CO2': '314.56',
#   'NB': '16',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '19',
#   'CO2': '313.69',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '20',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '21',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '22',
#   'CO2': '315.28',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '23',
#   'CO2': '315.28',
#   'NB': '18',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '24',
#   'CO2': '315.26',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '25',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '26',
#   'CO2': '314.78',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '27',
#   'CO2': '314.89',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '28',
#   'CO2': '314.85',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '29',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '30',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '08',
#   'Dy': '31',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '01',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '02',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '03',
#   'CO2': '315.05',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '04',
#   'CO2': '314.89',
#   'NB': '17',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '05',
#   'CO2': '314.68',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '06',
#   'CO2': '315.00',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '07',
#   'CO2': '315.09',
#   'NB': '8',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '08',
#   'CO2': '315.21',
#   'NB': '5',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '09',
#   'CO2': '315.06',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '10',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '11',
#   'CO2': '313.88',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '12',
#   'CO2': '314.14',
#   'NB': '18',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '13',
#   'CO2': '313.64',
#   'NB': '10',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '14',
#   'CO2': '314.80',
#   'NB': '12',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '15',
#   'CO2': '315.29',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '16',
#   'CO2': '312.39',
#   'NB': '7',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '17',
#   'CO2': '314.61',
#   'NB': '6',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '18',
#   'CO2': '314.68',
#   'NB': '9',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '19',
#   'CO2': 'NaN',
#   'NB': '0',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '20',
#   'CO2': '313.94',
#   'NB': '14',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '21',
#   'CO2': '313.38',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '22',
#   'CO2': '312.39',
#   'NB': '11',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '23',
#   'CO2': '313.56',
#   'NB': '15',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '24',
#   'CO2': '313.38',
#   'NB': '19',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '25',
#   'CO2': '313.44',
#   'NB': '2',
#   'scale': '12.0'},
#  {'Yr': '1960',
#   'Mn': '09',
#   'Dy': '26',
#   'CO2': '313.33',
#   'NB': '15',
#   'scale': '12.0'},
#  ...]

# %%
# TEST
co2_data = read_co2_csv('data/co2.csv')
assert co2_data[0] == {'Yr': '1958', 'Mn': '01', 'Dy': '01', 'CO2': 'NaN', 'NB': '0', 'scale': '12.0'}
print("All tests passed!")
# Out:
# All tests passed!

# %% [markdown]
# ## Step 2 - Reading in the CH4 data
#
# The methane data 'data/ch4.csv' comes from another source and the file has a slightly different format. This time comment lines start with a '#' symbol. There are 148 lines of comments at the start of the file. The 149th line contains the field names. The data starts on the 150th line. The fields are separated by spaces rather than commas.
#
# Write a function called 'read_ch4_csv' that takes the file name and returns a list of dictionaries storing the data. i.e. the 'ch4.csv' file would be read with,
#
# ```python
# ch4_data = read_csv('data/ch4.csv')
# ```

# %%
# WRITE SOLUTION HERE
import csv
def read_ch4_csv(filename):
    with open(filename,'r') as csvfile:
        lines = csvfile.readlines()
        lines = lines[148:]
        ch4_reader = csv.DictReader(lines, skipinitialspace = True, delimiter = ' ')
        data = [row for row in ch4_reader]
    return data

# %%
ch4_data = read_ch4_csv('data/ch4.csv')
print(list(ch4_data[0].keys()))
print(ch4_data[0]['site_code'])
# Out:
# ['site_code', 'year', 'month', 'day', 'hour', 'minute', 'second', 'time_decimal', 'value', 'value_std_dev', 'nvalue', 'latitude', 'longitude', 'altitude', 'elevation', 'intake_height', 'qcflag']
# MLO

# %%
# TEST
ch4_data = read_ch4_csv('data/ch4.csv')
assert ch4_data[0] == {'site_code': 'MLO', 'year': '1987', 'month': '1', 'day': '1', 'hour': '0', 'minute': '0', 'second': '0', 'time_decimal': '1987.0', 'value': '-999.99', 'value_std_dev': '-99.99', 'nvalue': '0', 'latitude': '19.536', 'longitude': '-155.576', 'altitude': '3437.0', 'elevation': '3397.0', 'intake_height': '40.0', 'qcflag': '*..'}
print("All tests passed!")
# Out:
# All tests passed!

# %% [markdown]
# ## Step 3 - Simplifying the data
#
# Now that we've read the two datasets into memory, we need to simplify them. You will see that that two datasets have a lot of different fields. We are only interested in the date and the concentration of the gas. It would be convenient to convert both datasets into a common format, i.e., a list of dictionaries with just four fields, 'year', 'month', 'day' and 'co2_concentration' (or 'ch4_concentration')
#
# Note, that these fields have different names in the two datasets. In the co2 data they are called 'Yr', 'Mn', 'Dy' and 'CO2'. In the ch4 data they are called 'year', 'month', 'day' and 'value'.
#
# Write a function called 'simplify_data' that takes two parameters: a list of dictionaries and a parameter called 'fields'. The fields parameter should be a dictionary that maps the field names in the original data to the field names in the simplified data. The function should return a list of dictionaries with the simplified data.
#
# For example, the co2 data would be simplified with the following call,
#
# ```python
# co2_data = simplify_data(co2_data, {'Yr':'year', 'Mn':'month', 'Dy':'day', 'CO2':'co2_concentration'})
# ```
#
# and the ch4 data would be simplified with the following call,
#
# ```python
# ch4_data = simplify_data(ch4_data, {'year':'year', 'month':'month', 'day':'day', 'value':'ch4_concentration'})
# ```

# %%
# WRITE SOLUTION HERE
def simplify_data(data,nd):
    newlist = []
    for d in data:
        n1d = {}
        for k in nd:
            n1d[k] = d[k]
        newlist.append(n1d)
    return newlist

# %%
ch4_data1 = simplify_data(ch4_data, {'year':'year', 'month':'month', 'day':'day', 'value':'ch4_concentration'})
print(ch4_data1[0])
# Out:
# [{'year': '1987', 'month': '1', 'day': '1', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '2', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '3', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '4', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '5', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '6', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '7', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '8', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '9', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '10', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '11', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '12', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '13', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '14', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '15', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '16', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '17', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '18', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '19', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '20', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '21', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '22', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '23', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '24', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '25', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '26', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '27', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '28', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '29', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '30', 'value': '-999.99'}, {'year': '1987', 'month': '1', 'day': '31', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '1', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '2', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '3', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '4', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '5', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '6', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '7', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '8', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '9', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '10', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '11', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '12', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '13', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '14', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '15', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '16', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '17', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '18', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '19', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '20', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '21', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '22', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '23', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '24', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '25', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '26', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '27', 'value': '-999.99'}, {'year': '1987', 'month': '2', 'day': '28', 'value': '-999.99'}, {'year': '1987', 'month': '3', 'day': '1', 'value': '-999.99'}, {'year': '1987', 'month': '3', 'day': '2', 'value': '-999.99'}, {'year': '1987', 'month': '3', 'day': '3', 'value': '- ...

# %%
# TEST
ch4_data1 = simplify_data(ch4_data, {'year':'year', 'month':'month', 'day':'day', 'value':'ch4_concentration'})
co2_data1 = simplify_data(co2_data, {'Yr':'year', 'Mn':'month', 'Dy':'day', 'CO2':'co2_concentration'})

assert ch4_data1[0] == {'year': '1987', 'month': '1', 'day': '1', 'ch4_concentration': '-999.99'}
assert co2_data1[0] == {'year': '1958', 'month': '01', 'day': '01', 'co2_concentration': 'NaN'}

print("All tests passed!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 5
#       2 ch4_data1 = simplify_data(ch4_data, {'year':'year', 'month':'month', 'day':'day', 'value':'ch4_concentration'})
#       3 co2_data1 = simplify_data(co2_data, {'Yr':'year', 'Mn':'month', 'Dy':'day', 'CO2':'co2_concentration'})
# ----> 5 assert ch4_data1[0] == {'year': '1987', 'month': '1', 'day': '1', 'ch4_concentration': '-999.99'}
#       6 assert co2_data1[0] == {'year': '1958', 'month': '01', 'day': '01', 'co2_concentration': 'NaN'}
#       8 print("All tests passed!")
#
# AssertionError:

# %% [markdown]
# ## Step 4 - Dealing with missing values
#
# The next thing to note is that the data is incomplete. For some days there is no concentrations data. In the ch4 data, these missing values are indicated by a value of -999.99. In the co2 data, these missing values are indicated by a value of 'NaN'. In the next step we are simply going to remove these entries from the list of dictionaries.
#
# Write a function called 'remove_missing_values' that takes a list of dictionaries and a parameter called 'missing_value'. The missing_value is the value that is used to mark missing data, i.e. 'NaN' for the co2 data. The function should return a list of dictionaries in which any entries that have missing values have been removed. Note, the missing values appear in the 'concentration' field in this case, but the function should check all the fields -- if any field has a missing value, the whole entry should be removed.

# %%
# WRITE SOLUTION HERE

# %%
# TEST
ch4_data = remove_missing_values(ch4_data, '-999.99')
co2_data = remove_missing_values(co2_data, 'NaN')
assert len(ch4_data) == 12111
assert len(co2_data) == 17685

# %% [markdown]
# ## Step 5 - Fixing the data types
#
# ### Step 5.1 - Fixing the types
#
# You will notice that all the values in the data are strings. We need to convert them to the appropriate data types. For example, the year, month and data should all be integers, the concentration should be a float.
#
# Write a function called 'fix_data_types' that takes a list of dictionaries and a parameter called field_types. The field_types parameter is a dictionary that maps field names to the appropriate data type. The function should return a list of dictionaries in which the values have been converted to the appropriate data types.
#
# For example, the co2 data would be converted with the following call,
#
# ```python
# co2_data = fix_data_types(co2_data, {'year':int, 'month':int, 'day':int, 'co2_concentration':float})
# ```
#
# Note the type of a value can be changed with the following syntax,
#
# ```python
# value = int(value)
# ```
#
# or if the type int is stored as a variable called 'my_type',
#
# ```python
# my_type = int
# value = my_type(value)
# ```

# %%
# WRITE SOLUTION HERE

# %%
# TEST
ch4_data = fix_data_types(ch4_data, {'year':int, 'month':int, 'day':int, 'ch4_concentration':float})
co2_data = fix_data_types(co2_data, {'year':int, 'month':int, 'day':int, 'co2_concentration':float})
assert type(ch4_data[0]['year']) == int
assert type(ch4_data[0]['month']) == int
assert type(ch4_data[0]['day']) == int
assert type(ch4_data[0]['ch4_concentration']) == float
print("All tests passed!")

# %% [markdown]
# ### Step 5.2 - Fixing the units
#
# There is a small detail that we must not miss. The co2 data and ch4 data both have entries called 'co2_concentration' and 'ch4_concentration' respectively. However, the units of these values are different. The co2 data is in parts per million (ppm) and the ch4 data is in parts per billion (ppb). To avoid later confusion, we need to convert the ch4 data to ppm.
#
# We could write a general function to do this but to keep things simple we'll write a function called 'convert_ch4_concentration_to_ppm' that takes a list of dictionaries and converts the 'ch4_concentration' field to ppm by dividing its value by 1000. The function should return a list of dictionaries in which the 'ch4_concentration' field has been converted to ppm.

# %%
# WRITE SOLUTION HERE

# %%
# TEST
ch4_data = convert_ch4_concentration_to_ppm(ch4_data)
assert ch4_data[0]['ch4_concentration'] == 1.70002
print("All tests passed!")

# %% [markdown]
# ## Step 6 - Making an index
#
# In the next step we are going to combine the co2 and ch4 data into a single list of dictionaries with entries for year, month, day, co2 concentration and ch4 concentration.
#
# This is not entirely straightforward because we can't assume that all dates have both a co2 and a ch4 reading and we can't assume that the data is in the same order in both lists. In fact, you'll see that the co2 data starts and 1958 and the ch4 data starts in 1987.
#
# In order to match up the entries we will add an index to each dictionary. The index is a field that has a unique value and will be the same when both entries correspond to each other, i.e., in this case it can be made by combining the year, month and day fields into a single data string. e.g '1958-3-29'.
#
# Write a function called 'make_index' that takes a list of dictionaries and a parameter called index_fields. The index_fields parameter is a list of the names of the fields to use to form the index. It should return a list of dictionaries with an extra field called 'index'. The value of the index field should be a string made by combining the values of the index_fields with a '-' character between them.
#
# For example, the co2 data would be converted with the following call,
#
# ```python
# co2_data = make_index(co2_data, ['year', 'month', 'day'])
# ```
#
# After this is done the co2_data will be a list of dictionaries with entries that look like,
#
# ```json
# {"year": 1958, "month": 3, "day": 29, "concentration": 315.71, "index": "1958-3-29"}
# ```

# %%
# WRITE SOLUTION HERE

# %%
co2_data = make_index(co2_data, ['year', 'month', 'day'])
ch4_data = make_index(ch4_data, ['year', 'month', 'day'])
assert co2_data[0] == {'year': 1958, 'month': 3, 'day': 30, 'co2_concentration': 316.16, 'index': '1958-3-30'}
assert ch4_data[0] == {'year': 1987, 'month': 4, 'day': 3, 'ch4_concentration': 1.70002, 'index': '1987-4-3'}
print("All tests passed!")

# %% [markdown]
# ## Step 7 - Joining the data
#
# ### Step 7.1 - The naive algorithm
#
# Now that we have an index we can join the two datasets together. We will do this by creating a new list of dictionaries with entries for year, month, day, co2 concentration and ch4 concentration.
#
# This is potentially a computationally expensive process. We will do it in a naive we first and then we'll implement a more efficient algorithm.
#
# When doing the merge we are looking for index entries that appear in both datasets.
#
# The basic approach requires a nested loop:
#
# - For each entry in the first dataset
#   - take the index (call this index1)
#   - for each entry in the second dataset
#     - take the index (call this index2)
#     - if index1 == index2
#       - create a new entry in the merged dataset with the fields from the first dataset and the fields from the second dataset
#
# Write a function called 'join_data' that takes two lists of dictionaries and returns a list of dictionaries with the merged data. The function should use the naive algorithm described above.
#
# Note, this might take a while to run. It takes about 7 seconds on my Macbook Pro.

# %%
# WRITE SOLUTION HERE

# %%
# TEST

joined_data = join_data(co2_data, ch4_data)
assert joined_data[0] == {'year': 1987, 'month': 4, 'day': 3, 'co2_concentration': 350.84, 'index': '1987-4-3', 'ch4_concentration': 1.70002}
print("All tests passed!")

# %% [markdown]
# ### Step 7.2 - A more efficient way to join data
#
# The previous algorithm is very inefficient because it has a nested loop that needs to run over all the entries in both datasets. This will be slow, and worse, it will scale with the order of the product of the number of entries in the two datasets.
#
# A more efficient approach is to make use of the fact that the index is unique. Rather than having to look through the second list to find the index, we could store that list as a dictionary, i.e. using the index as they key and the data entry's dictionary as the value.
#
# The new alogirithm would be:
#   - convert the second list of dictionaries into a dictionary with the index as the key (call this index_dict)
#   - for each entry in the first list of dictionaries
#     - take the index (call this index1)
#     - Lookup index1 in the index_dict, if it exists
#       - create a new entry in the merged dataset with the fields from the first entry
#
# Write a function called 'join_data_fast' that takes two lists of dictionaries and returns a list of dictionaries with the merged data using this faster approach

# %%
# WRITE SOLUTION HERE

# %%
# TEST
joined_data = join_data_fast(co2_data, ch4_data)
assert joined_data[0] == {'year': 1987, 'month': 4, 'day': 3, 'co2_concentration': 350.84, 'index': '1987-4-3', 'ch4_concentration': 1.70002}
print("All tests passed!")

# %% [markdown]
# You can time the two functions using the special `%timeit` function that is available in the Jupyter environment. For example, you can time the two functions with the following commands,
#
# ```python
# %timeit join_data(co2_data, ch4_data)
# ```
#
# and
#
# ```python
# %timeit join_data_fast(co2_data, ch4_data)
# ```
#
# Try this in the cell below.

# %%
# WRITE SOLUTION HERE

# %% [markdown]
# On my Macbook Pro the first takes about 6 seconds and the second takes about 3 milliseconds. That's a speed up of 2000 times!
#
# Using the right algorithm can make a huge difference to the performance of your code. Fortunately, we do not normally need to worry about this. Later in the module, we will be using Pandas for this type of processing. Not only does it have all these algorithms built in, but it is written in C, which makes it much faster than Python.

# %% [markdown]
# ## Step 8 - Processing the data
#
# Now that we have got the data into a single, simple format we can start to do some analysis.
#
# Our first task will be to reduce the co2 and ch4 concentrations into a single value. We are particularly interested in the warming effect that these gases have. For a given concentration, the warming effect of ch4 is much greater than that of co2, however, the picture is a bit complicated because ch4 also breaks down much faster than co2. These two effects can be combined into one number called the 'Global Warming Potential' (GWP). The GWP is a measure of the total warming effect of a gas over a given time period. The GWP of co2 is defined to be 1, the GWP of ch4 is 25. Using this we can calculate the total warming effect of a given concentration of ch4 by multiplying the concentration by 25. This is called the 'CO2 equivalent' (CO2e) concentration. We can then just sum of the CO2e values for all the gases that we want to consider.
#
# So lets add a new field to our data called co2e which will be formed by summing the co2 and ch4 concentrations multiplied by their GWP (i.e., 1 and 4 respectively).
#
# Write a function called 'add_co2e' that takes a list of dictionaries and returns a list of dictionaries with an extra field called 'co2e'. The value of the co2e field should be the sum of the co2 and ch4 concentrations multiplied by their GWP.

# %%
# WRITE SOLUTION HERE

# %%
# TEST 
co2e_data = add_co2e(joined_data)
assert co2e_data[0]['co2e'] == 393.34049999999996
print("All tests passed!")

# %% [markdown]
# ## Step 9 -- Plotting the data
#
# We are now ready to try and plot the data. We want to see a graph of the co2e concentration over time.
#
# We will perform the plot using the matplotlib library. This is a very powerful library for plotting data. It is also very complicated. We will only be using a small part of its functionality and we will look at how to use it in more detail later in the module.

# %%
import matplotlib.pyplot as plt

plt.plot([row['co2_concentration'] for row in co2e_data])
plt.plot([row['co2e'] for row in co2e_data])

# %% [markdown]
# ### Step 9.2 - Making a meaningful time axis
#
# In the previous plot, the x-axis is just the index number of the dictionary entry, i.e. it runs from 0 to about 9000. The plot makes some sort of sense because the data is sorted by date, but it would be much better if we could have a time axis that shows the date more meanigfully. One way to do this is to plot the data against a floating point number that represents the day in units of years in a fractional way, i.e. 1985.5 would be half way through 1985. This is called the 'decimal year' and it is a common way to plot time series data. Let's write a function that takes the year, month and day and returns the decimal year.
#
# Write a function called 'get_decimal_year' that takes three parameters, year, month and day and returns the decimal year. This is complicated by the fact that the months have different numbers of days. For your function, simplify it by considering all months to be exactly 1/12 of a year and all days to be exactly 1/365 of a year. This is not exactly correct, but it is good enough for our purposes.

# %%
# WRITE SOLUTION HERE

# %%
# TEST
print(get_decimal_year(1958, 3, 30))
assert get_decimal_year(1958, 3, 30) == 1958.2461187214612
assert get_decimal_year(1987, 1, 1) == 1987
print("All tests passed!")

# %% [markdown]
# Now write a function called add_decimal_year that adds a decimal_year field to each row of data. You can use the get_decimal_year function you just wrote.

# %%
# WRITE SOLUTION HERE

# %%
# TEST
co2e_data = add_decimal_year(co2e_data)
print(co2e_data[0]['decimal_year'])
assert co2e_data[0]['decimal_year'] == 1987.2554794520547
print("All tests passed!")

# %% [markdown]
# We will now replot the data using the decimal year for the x-axis.

# %%
plt.plot([row['decimal_year'] for row in co2e_data], [row['co2e'] for row in co2e_data])
plt.plot([row['decimal_year'] for row in co2e_data], [row['co2_concentration'] for row in co2e_data])

# %% [markdown]
# The plot below shows just the methane concentration over time. Note how it was was rising during the 90's and then seemed to level off during the 2000's. But, alarmingly, it started to rapidly rise again from about 2007 onwards. This is a worrying trend. As you can see from the previous plot, although methane concentrations are much lower than co2 concentrations, they make a significant contribution to the total global warming potential -- equivalent to over 50 ppm of CO2, or two decades worth of CO2 emission increases at current rates. So rapid increases in methane concentrations are a major concern.

# %%
plt.plot([row['decimal_year'] for row in co2e_data], [row['ch4_concentration'] for row in co2e_data])

# %% [markdown]
# *Copyright &copy; 2023 Jon Barker, University of Sheffield. All rights reserved*.

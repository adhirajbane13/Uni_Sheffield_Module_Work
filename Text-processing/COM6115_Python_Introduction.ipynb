# %% [markdown]
# # Basic printing / string formatting

# %%
print('Hello world!')
print("Hello world!")
print('''Hello world!''')
print("""Hello world!""")
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %%
print('this', 'that', sep='\n', end='\n\n.')
print('this', 'that')
# Out:
# this
# that
#
# .this that

# %%
module_name = 'COM6115 Text Processing'

print('This is the first lecture of ', module_name, '.')
print('This is the first lecture of ' + module_name + '.')
print('This is the first lecture of {}.'.format(module_name))
# Out:
# This is the first lecture of  COM6115 Text Processing .
# This is the first lecture of COM6115 Text Processing.
# This is the first lecture of COM6115 Text Processing.

# %%
my_pi = 3.141592
form = 'The value of %s (to 3 decimal places) is: %.2f'
print(form % ('PI', my_pi))
# Out:
# The value of PI (to 3 decimal places) is: 3.14

# %% [markdown]
# # Python lists

# %%
x = [ 'what', 'can', 'I', 'put', 'in', 'my', 'list' ]

# %% [markdown]
# How can we print the first element from the above list?

# %%
x[0]
# Out:
# 'what'

# %% [markdown]
# ### Using lists
#
# - Index
# - Negative position index
# - Slicing
# - Slicing with negative step
# - Assign values

# %%
#print(x[-2])
# x = [ 'what', 'can', 'I', 'put', 'in', 'my', 'list' ]
# x[1:4]

#x[1:6:2]

#x[::-1]

x[-2] = "this"
print(x)

x[5] = "my"
print(x)
# Out:
# ['what', 'can', 'I', 'put', 'in', 'this', 'list']
# ['what', 'can', 'I', 'put', 'in', 'my', 'list']

# %% [markdown]
# Append items and concatenate lists:

# %%
x = ['this']
y = ['that']
x.append('and') # add single item to end of list
print(x)
# Out:
# ['this', 'and']

# %%
z = x + y # '+' builds concatenated list
z
# Out:
# ['this', 'and', 'that']

# %% [markdown]
# # Control structures: if/then/else

# %%
mark = int(input("Please enter an integer mark: "))

if mark >= 50:
    print("Result: pass")
# Out:
# Please enter an integer mark: 40

# %%
mark = int(input("Please enter an integer mark: "))

if mark >= 50:
    print("Result: pass")
else:
    print("Result: fail")
# Out:
# Please enter an integer mark: 40
# Result: fail

# %%
mark = int(input("Please enter an integer mark: "))

if mark >= 70:
    print("Result: first")
elif mark >= 50:
    print("Result: pass")
else:
    print("Result: fail")
# Out:
# Please enter an integer mark: 80
# Result: first

# %% [markdown]
# # Control structures: loops — while

# %%
score = 1
while score > 0:
    score = int(input("Please enter score: "))
    print("Score was", score)
# Out:
# Please enter score: -2342
# Score was -2342

# %%
while True:
    print('Hello')

# %%
import time

timeout = 1 # second
start = time.time()

while True:
    print('Hello')
    now = time.time()
    if now >= start + timeout:
        break
# Out:
# Streaming output truncated to the last 5000 lines.
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %% [markdown]
# # Control structures: loops — for

# %%
mystring = 'this and that'
for c in mystring:
    print(c)
# Out:
# t
# h
# i
# s
#
# a
# n
# d
#
# t
# h
# a
# t

# %%
mystring = 'this and that'
for c in mystring:
    print(c, end='')
# Out:
# this and that

# %%
mystring = 'this and that'
for c in mystring.split():
    print(c)
# Out:
# this
# and
# that

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(3,7): # range(start, end)
    print(i)
# Out:
# 3
# 4
# 5
# 6

# %%
for i in range(0,10,2):  # range(start, end, step)
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(10,0,-2):  # range(start, end, negative step)
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
scores = [5, 12, 7, 15]
for value in scores:
    if value > 10:
        print(value)
# Out:
# 12
# 15

# %%
scores = [5, 12, 7, 15]
for i in range(len(scores)):
    scores[i] = scores[i] + 2
print(scores)
# Out:
# [7, 14, 9, 17]

# %% [markdown]
# # User-defined functions

# %%
def convert_distance(miles):
    kilometers = (miles * 8.0) / 5.0
    return kilometers

# %%
print(convert_distance(40))
# Out:
# 64.0

# %% [markdown]
# # Dictionaries

# %%
tel = { }
tel['alf'] = 111 # new key, assign value
tel['bob'] = 222 # new key, assign value
tel['cal'] = 333 # new key, assign value
print(tel)
# Out:
# {'alf': 111, 'bob': 222, 'cal': 333}

# %%
print(tel['bob']) # access a value
# Out:
# 222

# %%
tel['bob'] = 555 # update a value
print(tel)
# Out:
# {'alf': 111, 'bob': 555, 'cal': 333}

# %%
#print('alf' in tel) # check item is a key
print('dan' in tel) # again, check item is a key
# Out:
# False

# %%
print(tel['dan'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-9e9847a6df94> in <cell line: 1>()
# ----> 1 print(tel['dan'])
#
# KeyError: 'dan'

# %%
k = 'eric'
if k in tel:
    print(k, ':', tel[k])
else:
    print(k, 'not found!')
# Out:
# eric not found!

# %%
print(tel)
# Out:
# {'alf': 111, 'bob': 555, 'cal': 333}

# %%
for k in tel:
    print(k, ':', tel[k])
# Out:
# alf : 111
# bob : 555
# cal : 333

# %% [markdown]
# # Sorting lists

# %%
x = [7,11,3,9,2]

print('sorted(x) =', sorted(x))
print('x =', x)
# Out:
# sorted(x) = [2, 3, 7, 9, 11]
# x = [7, 11, 3, 9, 2]

# %%
x.sort()
print('x =', x)
# Out:
# x = [2, 3, 7, 9, 11]

# %%
x = [7,11,3,9,2]
y = sorted(x, reverse=True)

print(y)
# Out:
# [11, 9, 7, 3, 2]

# %%
x = [('a', 3), ('c', 1), ('b', 5)]
print(sorted(x))
# Out:
# [('a', 3), ('b', 5), ('c', 1)]

# %% [markdown]
# Keyword `key` allows you to supply a (single arg) function, that compute some alternate value from an item. The items of list then sorted on basis of these alternate values.
#
# Lambda notation allows us to create temporary functions (so that we don't have to define them, as previously shown).

# %%
print(sorted(x, key=lambda i:i[1])) # sorting list of pairs (tuples) by second value
# Out:
# [('c', 1), ('a', 3), ('b', 5)]

# %% [markdown]
# # Sorting dictionaries

# %% [markdown]
# Sorting a dictionary by key:

# %%
counts = {'a': 3, 'c': 1, 'b': 5}

print('counts =', counts, end='\n\n')
print('sorted(counts) =', sorted(counts), end='\n\n')
print('sorted(counts, key=lambda v:counts[v]) =', sorted(counts, key=lambda v:counts[v]), end='\n\n')
print('sorted(counts, key=lambda v:counts[v], reverse=True) =', sorted(counts, key=lambda v:counts[v], reverse=True), end='\n\n')
# Out:
# counts = {'a': 3, 'c': 1, 'b': 5}
#
# sorted(counts) = ['a', 'b', 'c']
#
# sorted(counts, key=lambda v:counts[v]) = ['c', 'a', 'b']
#
# sorted(counts, key=lambda v:counts[v], reverse=True) = ['b', 'a', 'c']

# %% [markdown]
# Sorting a dictionary by value:

# %%
densities = {'iron':7.8, 'gold':19.3, 'zinc':7.13, 'lead':11.4}

for metal in sorted(densities, reverse=True, key=lambda m:densities[m]):
    print('%8s = %5.1f' % (metal, densities[metal]))
# Out:
#     gold =  19.3
#     lead =  11.4
#     iron =   7.8
#     zinc =   7.1

# %%
# alternative way to print, using f-strings

for metal in sorted(densities, reverse=True, key=lambda m:densities[m]):
    print(f'{metal: >8} = {densities[metal]: >5.1f}')
# Out:
#     gold =  19.3
#     lead =  11.4
#     iron =   7.8
#     zinc =   7.1

# %%
var = "world"
print("hello {}".format(var))
# Out:
# hello world

# %%
print(f"hello {var}")
# Out:
# hello world
